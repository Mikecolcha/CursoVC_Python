# %% [markdown]
# OPENCV
# IMÁGENES Y MATRICES
#
# NOMBRE: MICHAEL COLCHA

# %%
# Importar imagen
import cv2 as cv
import matplotlib.pyplot as plt

# Lectura de una imagen
img = cv.imread("Pic/dh.png")

# Mostrar imagen
plt.imshow(img)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread("Pic/dh.png", cv.IMREAD_GRAYSCALE)
plt.imshow(img, cmap="gray")

# %%
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread("Pic/dh.png", cv.IMREAD_COLOR)
plt.imshow(img, cmap="gray")

# %% [markdown]
# VENTANA EMERGENTE

# %%
import cv2 as cv
# Leer la imagen
img = cv.imread("Pic/dh.png")
cv.imshow("Digital-Hazard",img)
# Cerrar la imagen
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# GUARDAR IMAGEN

# %%
import cv2 as cv
img = cv.imread("Pic/dh.png")
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imwrite("Pic/dh2.jpg", img_gray)
# Out:
# True

# %% [markdown]
# LECTURA Y ESCRITURA DE VIDEO

# %% [markdown]
# CARGAR VIDEO

# %%
import numpy as np
import cv2 as cv
# Crear un objeto con el video
cap = cv.VideoCapture("Pic/Vid.mp4")
# Crear bucle

while(cap.isOpened()):
    ret,frame = cap.read()
    if ret:
        cv.imshow("Ángeles",frame)
        if(cv.waitKey(10) & 0xFF ==ord("q")):
            break
    else:
            break
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# ACCEDER A LA CÁMARA

# %%
import numpy as np
import cv2 as cv
# Crear dirección de la cámara
cap = cv.VideoCapture(0)
# creamos un bucle
while(cap.isOpened()):
    ret,frame = cap.read()
    if ret:
        cv.imshow("CÁMARA", frame)
        if(cv.waitKey(10) & 0xFF ==ord("q")):
            break
    else:
        break
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# FUNCIONES PARA DIBUJAR FIGURAS
#
# DIBUJAR LÍNEA

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# crear imagen
img = np.zeros((1000,1640,3), np.uint8)
# Se dibuja la línea
# cv.line(img, cordendas iniciales, cordenadas finales,color , grosor )
cv.line(img,(100,150),(550,650),(255,0,0),6)
cv.line(img,(550,650),(1400,40),(0,255,0),6)
# Mostrar imagen
plt.imshow(img)

# %% [markdown]
# DIBUJAR CÍRCULO

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# Crear imagen
img = np.zeros((500,500,3), np.uint8)
# Dibujar círculo
#cv.circle(img, condenadas centrales, radio, color, grosor)
cv.circle(img,(250,250), 100,(255,0,255),4)
# Mostrar imagen
plt.imshow(img)

# %% [markdown]
# DIBUJAR RECTÁNGULO

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# Crear imagen
img = np.zeros((600,600,3), np.uint8)
# Dibujar círculo
#cv.rectangle(img, cordenada esquina superior izquierda, cordenada de la esquina inferior derecha, color, grosor)
cv.rectangle(img,(50,50),(500,500),(255,255,0),2)
# Mostrar imagen
plt.imshow(img)

# %% [markdown]
# CAPTURA DE EVENTOS DESDE EL RATÓN

# %%
import cv2 as cv
clicked = False
# Función encargada de capturar el click del mouse
def onMouse(evento,x,y,flags,param):
    # variable global
    global clicked
    if(evento ==cv.EVENT_LBUTTONUP):
        clicked =True
# Crear objeto cv.VideoCapture()
camCap = cv.VideoCapture(0)
cv.namedWindow("Cámara")
# Configurar que se envie a la funcion onMouse los eventos del mouse
cv.setMouseCallback("Cámara",onMouse)
print("Mostrando Cámara, Presione en la Ventana para detener")
ret,frame = camCap.read()
while(ret and cv.waitKey(1)==-1 and not clicked):
    cv.imshow("Cámara", frame)
    ret,frame = camCap.read()
camCap.release()
cv.destroyAllWindows()
# Out:
# Mostrando Cámara, Presione en la Ventana para detener

# %%
import cv2 as cv
events = [i for i in dir(cv) if 'EVENT' in i ]
events
# Out:
# ['EVENT_FLAG_ALTKEY',
#  'EVENT_FLAG_CTRLKEY',
#  'EVENT_FLAG_LBUTTON',
#  'EVENT_FLAG_MBUTTON',
#  'EVENT_FLAG_RBUTTON',
#  'EVENT_FLAG_SHIFTKEY',
#  'EVENT_LBUTTONDBLCLK',
#  'EVENT_LBUTTONDOWN',
#  'EVENT_LBUTTONUP',
#  'EVENT_MBUTTONDBLCLK',
#  'EVENT_MBUTTONDOWN',
#  'EVENT_MBUTTONUP',
#  'EVENT_MOUSEHWHEEL',
#  'EVENT_MOUSEMOVE',
#  'EVENT_MOUSEWHEEL',
#  'EVENT_RBUTTONDBLCLK',
#  'EVENT_RBUTTONDOWN',
#  'EVENT_RBUTTONUP']

# %% [markdown]
# EVENTOS DEL RATÓN

# %%
import numpy as np
import cv2 as cv
def draw_circle(event, x, y, flags, param):
    if(event == cv.EVENT_LBUTTONDBLCLK):
        cv.circle(img, (x, y), 25, (255,0,0), -1 )
img = np.zeros((512,512,3), np.uint8)
cv.namedWindow('Dibujando Circulos')
cv.setMouseCallback('Dibujando Circulos', draw_circle)
while(True):
    cv.imshow('Dibujando Circulos',img)
    if (cv.waitKey(1) & 0xFF ==ord('q')):
        break
cv.destroyAllWindows()

# %% [markdown]
# DEBER 1

# %%
import numpy as np
import cv2 as cv
# Función de dibujar círculos
def draw_circle_rectangule(event, x, y, flags, param):
    if(event == cv.EVENT_LBUTTONDOWN):
        cv.circle(img, (x, y), 25, (255,0,0), -1 )
# Función de dibujar cuadrados
    elif(event == cv.EVENT_RBUTTONDOWN):
        cv.rectangle(img, (x, y), (x+50, y+50), (255,255,0), 2 )
# Crear
img = np.zeros((600,600,3), np.uint8)
cv.namedWindow('DIBUJANDO')
cv.setMouseCallback('DIBUJANDO', draw_circle_rectangule)
while(True):
    cv.imshow('DIBUJANDO',img)
    if (cv.waitKey(1) & 0xFF ==ord('q')):
        break
cv.destroyAllWindows()

# %%
# Importar imagen
import cv2 as cv
import matplotlib.pyplot as plt

# Lectura de una imagen
img = cv.imread("Pic/D1.png")

# Mostrar imagen
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
